# %% [markdown]
# ### 1.1. 네이터 뉴스 기사에서 제목과 본문을 추출
# #### - 네이버 뉴스기사(news.naver.com)의 URL을 입력했을 때 뉴스기사의 제목과 본문을 추출하는 코드

# %%
# 웹 페이지 다운로드를 위한 패키지
import requests
# HTML 분석을 위한 패키지
from bs4 import BeautifulSoup

# %%
# URL을 입력하면 웹 페이지에서 제목과 본문을 추출하는 함수
def read_naver_news(url):
  try:
    raw = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
  except:    
    return None  # 페이지가 존재하지 않거나 접속이 불가능한 경우  
  print("HTML 파일", raw.text[0:300]) # 가공되지 않은 HTML 파일 출력(앞의 300개 문자만 출력)

  html = BeautifulSoup(raw.text, "html.parser") # BeautifulSoup로 HTML 파일 분석
  
  # 제목부분 얻기
  title_part = html.find("h2", class_="media_end_head_headline")

  if title_part is None:
    title_part = ""   # 제목이 없는 경우 공백을 입력
  else:    
    title_part = title_part.get_text().replace("\n", "") # 줄바꿈문자(\n)가 들어간 경우 삭제
  print("\n뉴스기사 제목 :", title_part) # 제목부분 출력

  # 본문 얻기
  content_part = html.find('div', id="newsct_article").get_text()
  if content_part is None:
    print("뉴스기사 본문이 존재하지 않습니다!")
    return None   # 본문이 없는 경우  
  print("뉴스기사 본문 :", content_part) # 뉴스기사 본문 출력

  return (title_part, content_part)  # (제목, 본문) 튜플을 반환

# %%
# 네이버 뉴스기사 URL
test_url = "https://n.news.naver.com/mnews/article/028/0002608023?sid=101"

# %%
# 제목과 본문 텍스트 얻기
title, contents = read_naver_news(test_url)
# Out:
# HTML 파일
# <!doctype html>
# <html lang="ko" data-useragent="Mozilla/5.0">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="
#
# 뉴시기사 제목
# 제조업 경기전망 5분기째 부정적…대기업이 더 암울
#
# 뉴스기사 본문
#
#
# 대기업 BSI 중기보다 낮아“주력 수출업종 부진 영향”
#
#
#
# 연합뉴스국내 제조업 경기 전망이 5분기 연속 부정적으로 나타났다. 주력 수출 업종인 반도체·전자·철강·화학 등이 부진하면서 대기업 체감경기가 중견·중소기업보다 더 나빠졌다.대한상공회의소는 28일 전국 2172개 제조업체를 대상으로 조사(8월23~9월5일)한 올해 4분기 경기전망지수(BSI)가 81로, 지난 3분기(79)와 큰 차이없이 5분기째 부정적 전망이 이어졌다고 밝혔다. 이 지수가 100 이상이면 해당 분기의 경기를 이전 분기보다 긍정적으로 보는 기업이 많은 것이고, 100 이하면 그 반대다.업종별로는 조선·부품(103), 의료·정밀(102)을 제외한 모든 업종에서 경기전망지수가 100을 넘지 못했다. 원자재 국외 의존도가 높은 비금속광물(70)이 가장 부진했는데, 공급망 차질에 고환율이 겹친 때문으로 상의는 분석했다. 기업 규모별로 보면 대기업 경기전망지수(69)가 중견·중소기업(82)보다 낮았다. 국내 수출 대기업의 주력 업종인 반도체, 정보기술·전자, 철강, 화학 업종의 경기전망이 모두 부진한 영향으로 풀이된다.대한상의 관계자는 “연말 즈음에 풀릴 것으로 봤던 대외 경기가 오히려 악화하거나 내년까지 장기화할 것으로 예상되면서, 수출 비중이 높아 글로벌 경기나 환율 등 대외 변수에 더 민감한 대기업에서 부정적 전망이 강하게 나타났다”고 분석했다. 올해 실적이 목표치를 달성할 수 없다고 보는 기업이 49.8%였다. 목표치를 달성하거나 이에 근접할 것이란 기업은 45.3%, 목표치를 초과할 것으로 보는 기업은 4.9%였다. 올해 실적에 영향을 미칠 것으로 예상하는 주요 리스크(중복응답)로는 원가 상승 및 원자재 수급 불안(82.1%)을 가장 많이 꼽았다. 이어 환율 등 대외 경제지표 변동성 심화(47.2%), 금리인상 기조(46.9%), 인플레이션에 따른 민간소비 위축(27.0%), 주요국 경기 둔화로 인한 수출 부진(19.5%), 미-중 갈등 등 공급망 리스크(18.9%), 기업 부담 법안 등 정책 리스크(7.8%) 등이었다.

# %%
print("뉴스기사 제목 :", title)
# Out:
# 뉴스기사 제목 : 제조업 경기전망 5분기째 부정적…대기업이 더 암울

# %%
print("뉴스기사 본문\n", contents)
# Out:
# 뉴스기사 본문
#
#
# 대기업 BSI 중기보다 낮아“주력 수출업종 부진 영향”
#
#
#
# 연합뉴스국내 제조업 경기 전망이 5분기 연속 부정적으로 나타났다. 주력 수출 업종인 반도체·전자·철강·화학 등이 부진하면서 대기업 체감경기가 중견·중소기업보다 더 나빠졌다.대한상공회의소는 28일 전국 2172개 제조업체를 대상으로 조사(8월23~9월5일)한 올해 4분기 경기전망지수(BSI)가 81로, 지난 3분기(79)와 큰 차이없이 5분기째 부정적 전망이 이어졌다고 밝혔다. 이 지수가 100 이상이면 해당 분기의 경기를 이전 분기보다 긍정적으로 보는 기업이 많은 것이고, 100 이하면 그 반대다.업종별로는 조선·부품(103), 의료·정밀(102)을 제외한 모든 업종에서 경기전망지수가 100을 넘지 못했다. 원자재 국외 의존도가 높은 비금속광물(70)이 가장 부진했는데, 공급망 차질에 고환율이 겹친 때문으로 상의는 분석했다. 기업 규모별로 보면 대기업 경기전망지수(69)가 중견·중소기업(82)보다 낮았다. 국내 수출 대기업의 주력 업종인 반도체, 정보기술·전자, 철강, 화학 업종의 경기전망이 모두 부진한 영향으로 풀이된다.대한상의 관계자는 “연말 즈음에 풀릴 것으로 봤던 대외 경기가 오히려 악화하거나 내년까지 장기화할 것으로 예상되면서, 수출 비중이 높아 글로벌 경기나 환율 등 대외 변수에 더 민감한 대기업에서 부정적 전망이 강하게 나타났다”고 분석했다. 올해 실적이 목표치를 달성할 수 없다고 보는 기업이 49.8%였다. 목표치를 달성하거나 이에 근접할 것이란 기업은 45.3%, 목표치를 초과할 것으로 보는 기업은 4.9%였다. 올해 실적에 영향을 미칠 것으로 예상하는 주요 리스크(중복응답)로는 원가 상승 및 원자재 수급 불안(82.1%)을 가장 많이 꼽았다. 이어 환율 등 대외 경제지표 변동성 심화(47.2%), 금리인상 기조(46.9%), 인플레이션에 따른 민간소비 위축(27.0%), 주요국 경기 둔화로 인한 수출 부진(19.5%), 미-중 갈등 등 공급망 리스크(18.9%), 기업 부담 법안 등 정책 리스크(7.8%) 등이었다.

# %% [markdown]
# ### 1.2. YouTube API를 사용하여 한국은행 관련 영상과 댓글 수집하기
# #### - YouTube API를 사용하기 위해서는 구글 계정이 필요하고 어플리케이션을 새로 등록한 후 API_KEY를 받아야 함
# #### - 무료로 API를 사용할 수 있는 할당량(1만회/일, API 종류에 따라 다름)이 정해져 있음
# #### YouTube API 관련하여 자세한 사항은 API reference를 참고
# ##### * https://developers.google.com/youtube/v3/docs?hl=ko)

# %%
# YouTube API 
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
from datetime import datetime
from dateutil.relativedelta import *
from tqdm import notebook
from os.path import join

# %%
# API_KEY
API_KEY = 'AIzaSyAyQypeNc_M_no9Yv-O9CEVS2BrrFQCwG0'

# 서비스 이름 (youtube API v3 사용)
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# YouTube API 사용을 위한 build 객체 생성
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)

# %%
# 검색어
QUERY = "한국은행"

# %%
# YouTube video list api descripiton (https://developers.google.com/youtube/v3/docs/videos/list?hl=ko)

# 영상 목록 검색
video_list = youtube.search().list(
    q = QUERY,
    order = "viewCount",    # 조회수가 높은 항목부터 결과로 보여주기
    part = "snippet",
    maxResults = 100,       # 한번에 보여줄 결과 갯수
    type = "video"          # 플레이리스트, 채널은 검색결과에서 제외
).execute()

# %%
video_list
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'hu2T4SJcrPXETylA7BarpQl2dDM',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'NL',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'mWFXRU07u9OALNASDEB02G9WfAs',
#    'id': {'kind': 'youtube#video', 'videoId': 'V5xVcFhIX2s'},
#    'snippet': {'publishedAt': '2022-08-03T02:07:28Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '[자막뉴스] 덜컥 다가온 외환위기 악몽...다급해진 한국은행 / YTN',
#     'description': '7월 소비자물가가 1년 전보다 6.3% 올랐습니다. 외환위기 때인 1998년 11월의 6.8% 이후 가장 높은 수치입니다. 또, 6월에 이어 두 달 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V5xVcFhIX2s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/V5xVcFhIX2s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/V5xVcFhIX2s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-03T02:07:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P3haNoYWT74dh0qKAV24bMyrQmk',
#    'id': {'kind': 'youtube#video', 'videoId': 'Jdq7Ztc9XLE'},
#    'snippet': {'publishedAt': '2022-01-25T09:15:00Z',
#     'channelId': 'UC9HNi_aAXBgpI2zhibOAfAA',
#     'title': '독일 은행원 언니, 여동생 따라 간 은행에 충격! (한국은행 실제반응 ㅋㅋ)',
#     'description': '독일 은행에서 일하는 에밀리의 친언니, 아나! 아나가 한국은행에서 보고 놀란 장면들이 있다는데...? ♥영상이 재미있으셨다면 구독 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Jdq7Ztc9XLE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Jdq7Ztc9XLE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Jdq7Ztc9XLE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '어썸 코리아 Awesome KOREA',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-25T09:15:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GXuFajtEriTnK77HIU_O10IvBoE',
#    'id': {'kind': 'youtube#video', 'videoId': 'k-EQ7ofeTYw'},
#    'snippet': {'publishedAt': '2022-09-27T08:12:02Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '[에디터픽] &quot;韓, 아시아서 가장 위험&quot;..&#39;제2 IMF&#39; 경고 / YTN',
#     'description': '1.\'킹달러\' 세계 금융시장 강타...총성 없는 \'환율 전쟁\'(김상우 기자) 2.OECD "내년 세계 경제 성장 더 둔화"(이종수 기자) 3.[굿모닝 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/k-EQ7ofeTYw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/k-EQ7ofeTYw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/k-EQ7ofeTYw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-27T08:12:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SGAHlvxPiMsUDiJGNB78B-obfNU',
#    'id': {'kind': 'youtube#video', 'videoId': 'vfGY0qycl1g'},
#    'snippet': {'publishedAt': '2022-08-17T10:44:16Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '[자막뉴스] 영끌족 &#39;발등에 불&#39;...한은 총재까지 &#39;섬뜩한 경고&#39; / YTN',
#     'description': '은행권 주택담보대출 변동금리의 기준인 코픽스가 7월에 0.52%포인트 상승해 2.90%가 됐습니다. 이는 지난 2010년 1월 코픽스가 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vfGY0qycl1g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vfGY0qycl1g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vfGY0qycl1g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-17T10:44:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QeMLMv9BMld2imBbrJ3ISN4mdJs',
#    'id': {'kind': 'youtube#video', 'videoId': '6WaB2fGpNN4'},
#    'snippet': {'publishedAt': '2022-09-19T08:32:21Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '[자막뉴스] 美가 쏘아올린 시한폭탄...벼랑 끝 한국은행 / YTN',
#     'description': '미국의 문제도 역시 인플레이션입니다. 지난달 소비자물가는 1년 전보다 8.3% 올라서 시장의 예상치를 뛰어넘었습니다. 두 차례 연속 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6WaB2fGpNN4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6WaB2fGpNN4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6WaB2fGpNN4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-19T08:32:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'U4-CIAJKR_NNoxqFf81t1c31-OU',
#    'id': {'kind': 'youtube#video', 'videoId': 'X4hu18IWRak'},
#    'snippet': {'publishedAt': '2019-06-06T06:00:02Z',
#     'channelId': 'UCCG6BEYjfQMGzypJw2EJCDQ',
#     'title': '30년 동안 상여금 투자해서 1000억 수익 낸 한국은행 직원의 투자법은? 30년간 한국은행에서 근무한 홍지안 머니큐레이터의 돈이야기 | 815머니톡',
#     'description': '실전 재테크 스터디, 815머니톡에서 저와 함께 하시죠!^^ "2000년 이후 한국의 신흥부자들" 책의 저자인 홍지안 머니큐레이터와 한국 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/X4hu18IWRak/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/X4hu18IWRak/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/X4hu18IWRak/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '815머니톡',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-06-06T06:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PiCVl2gvRo4VDHT1SuKMSwdIKNU',
#    'id': {'kind': 'youtube#video', 'videoId': 'kTfehtdMjOY'},
#    'snippet': {'publishedAt': '2022-03-18T11:21:07Z',
#     'channelId': 'UCfq4V1DAuaojnr2ryvWNysw',
#     'title': '[단독]한국은행 총재 후임에 이창용 IMF 국장으로 가닥 | 뉴스A',
#     'description': '[단독]한국은행 총재 후임에 이창용 IMF 국장으로 가닥 꽉 막혔던 회동 어디서 돌파구가 뚫린 걸까, 저희가 취재를 했는데요. 바로 한국 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kTfehtdMjOY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kTfehtdMjOY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kTfehtdMjOY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '채널A 뉴스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-18T11:21:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'k1HpqqP9uSrXJNjbQsibvSX1KY0',
#    'id': {'kind': 'youtube#video', 'videoId': '-7h0pCbKAL0'},
#    'snippet': {'publishedAt': '2022-07-13T11:07:08Z',
#     'channelId': 'UCsU-I-vHLiaMfV_ceaYz5rQ',
#     'title': '한은총재가 &#39;영끌족&#39;에게…&quot;이자 평생 3%라 생각 말아야&quot; / JTBC 뉴스룸',
#     'description': '한국은행 총재가 내놓은 메시지가 아주 의미심장합니다. 이자가 평생 3% 정도라고 생각하면 안 된다, 위험을 생각하라는 얘기 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-7h0pCbKAL0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-7h0pCbKAL0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-7h0pCbKAL0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JTBC News',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-13T11:07:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'D2S5sLeWqVtWCXrU-KVwQV27iDk',
#    'id': {'kind': 'youtube#video', 'videoId': 'ltGqS4EsaqM'},
#    'snippet': {'publishedAt': '2022-07-15T13:18:48Z',
#     'channelId': 'UC01cjDv7Zd3c1kXUCP9DngA',
#     'title': '이게 공정한 걸까? #shorts #윤석열 #대통령 #한국은행 #금리인상 #청년 #빚 #코인 #부동산 #투자 #대출 #돌려막기 #영끌 #손실 #세금',
#     'description': '채널 멤버쉽 가입 https://www.youtube.com/channel/UC01cjDv7Zd3c1kXUCP9DngA/join.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ltGqS4EsaqM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ltGqS4EsaqM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ltGqS4EsaqM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '벤자민의[C급]리포트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-15T13:18:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1nu4t-NIVkcL4IrtAj51DjbhSoc',
#    'id': {'kind': 'youtube#video', 'videoId': 'JYlfTIJDNZU'},
#    'snippet': {'publishedAt': '2022-03-18T12:30:10Z',
#     'channelId': 'UC-ORGzN6c-OZyCw9YAYNjkA',
#     'title': '한국은행 총재, 윤석열이 임명! (진성호의 융단폭격)',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JYlfTIJDNZU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JYlfTIJDNZU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JYlfTIJDNZU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '진성호방송',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-18T12:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'EWs9suUvR2-cpH7qP22BnFSnu8U',
#    'id': {'kind': 'youtube#video', 'videoId': 'dzW8dw5kwNc'},
#    'snippet': {'publishedAt': '2022-09-22T09:41:43Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '[자막뉴스] 입장 바꾼 한국은행...&#39;영끌족&#39; 큰일났다 / YTN',
#     'description': '지난 7월 금융통화위원회에서 한은 역사상 처음으로 빅스텝, 즉 0.5%포인트 기준금리 인상을 단행한 이창용 한국은행 총재. 미 연준의 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dzW8dw5kwNc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dzW8dw5kwNc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dzW8dw5kwNc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-22T09:41:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7uom1eFQE2LTAhCQbcIaO2BI3oY',
#    'id': {'kind': 'youtube#video', 'videoId': 'oVcnmdjj8yc'},
#    'snippet': {'publishedAt': '2019-06-23T15:52:08Z',
#     'channelId': 'UCoROtLOzsB4pAMarab00ANQ',
#     'title': '한국은행 충격발표 - 2020년 집값폭락',
#     'description': '멤버십 가입 : https://www.youtube.com/user/hsdjang8/join 후원 : 신한 110-341-158444 (라이트하우스) 개인상담(유료) ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oVcnmdjj8yc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oVcnmdjj8yc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oVcnmdjj8yc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '라이트하우스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-06-23T15:52:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vUmHuk2DVwPxWHW6ieJzC1sH5eo',
#    'id': {'kind': 'youtube#video', 'videoId': '3CC-ck_GnMo'},
#    'snippet': {'publishedAt': '2021-06-15T08:10:21Z',
#     'channelId': 'UCfGc9lfwtuwTZ3mrzJE-ZIA',
#     'title': '[넥스트사이언스|우리기술투자] 한국은행 &#39;디지털원화&#39; 모의투자 시행!! 초단기간 210% 폭등! 제2의 넥스트사이언스! 삼성까지 잡은 디지털화폐株! [오창록 전문가]',
#     'description': '오늘의 모두투자그룹 히든 급등주 받아보기 ▽▽ http://dns.ademotion.co.kr/event/modu/inx2_iss.html ↑↑↑위 주소로 신청시 무료 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3CC-ck_GnMo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3CC-ck_GnMo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3CC-ck_GnMo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '모두투자그룹',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-15T08:10:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1o0XQ37n8dMxOsxswS9IT6G6y4M',
#    'id': {'kind': 'youtube#video', 'videoId': '4ZbUSxouqu0'},
#    'snippet': {'publishedAt': '2021-04-27T00:51:51Z',
#     'channelId': 'UCwTeqOOcb4o64be9MnmxUUA',
#     'title': '전 한국은행 총재 박승이 말하는 향후 부동산 전망[더 구루 우리 시대의 원로]',
#     'description': '부동산전망 #부동산 #박승 #구루 전 한국은행 총재 박승 부동산 불패론에 대해 말하다 그가 전망하는 향후 부동산 전망은? #더구루 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4ZbUSxouqu0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4ZbUSxouqu0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4ZbUSxouqu0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SBS Biz 날리지 knowledge',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-04-27T00:51:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'URXK4zrkFd_xW23kjnYGdPVPT5s',
#    'id': {'kind': 'youtube#video', 'videoId': 'A1bD23Re1IM'},
#    'snippet': {'publishedAt': '2022-09-15T06:40:23Z',
#     'channelId': 'UCF4Wxdo3inmxP-Y59wXDsFw',
#     'title': '[뉴스외전 경제 &#39;쏙&#39;] 한국은행‥금리 올려도 고민, 안 올려도 고민 (2022.09.15/뉴스외전/MBC)',
#     'description': '출연 : 박연미 경제평론가 "뉴욕증시, \'물가 충격\' 급락 하루 만에 소폭 반등‥일시적 반발 매수 유입 영향인 듯" "국내 증시도 장초반 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/A1bD23Re1IM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/A1bD23Re1IM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/A1bD23Re1IM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MBCNEWS',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-15T06:40:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xW4ZFHGOXk6MBhNLGKQtfmwfuH4',
#    'id': {'kind': 'youtube#video', 'videoId': 'e0oH9gmviSE'},
#    'snippet': {'publishedAt': '2022-03-28T23:00:13Z',
#     'channelId': 'UCUHhXBQK8uku9OmCgeIApGg',
#     'title': '한국 은행에 돈뽑으러간 미국 전직 은행원 한국인들의 다 똑같은 행동 보고 경악한 이유 &quot;한국인들은 겁이 없는거에요?&quot;',
#     'description': '해외반응#해외네티즌반응#외국인반응 한국 은행에 돈뽑으러간 미국 전직 은행원 한국인들의 다 똑같은 행동 보고 경악한 이유 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/e0oH9gmviSE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/e0oH9gmviSE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/e0oH9gmviSE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '생생튜브',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-28T23:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ibVbhKhBnUJ6eQQ2WCeEa8qreGc',
#    'id': {'kind': 'youtube#video', 'videoId': 'TYKmsvPxuBY'},
#    'snippet': {'publishedAt': '2018-10-12T04:45:00Z',
#     'channelId': 'UCR0VAgd0w8QI7WWQ0E8Srdw',
#     'title': '2부 「트」 「승인」 발언, 미 재무부 한국은행 경고/ 미, 한국에 강경선회 통보! [세밀한 안보](2018.10.12)',
#     'description': '2부 「트」 「승인」 발언, 미 재무부 한국은행 경고/ 미, 한국에 강경선회 통보! [세밀한 안보](2018.10.12) 미래경영연구소회원모집 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TYKmsvPxuBY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TYKmsvPxuBY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TYKmsvPxuBY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '황장수의 뉴스브리핑o',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-10-12T04:45:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hCKIo1WypJkK1t-10jDCZICFsk8',
#    'id': {'kind': 'youtube#video', 'videoId': 'g_eil4_O5TY'},
#    'snippet': {'publishedAt': '2022-07-13T23:09:51Z',
#     'channelId': 'UC5HSw5OY2vfVFSihpiB-AVQ',
#     'title': '한국은행 기준금리 0.5% 인상 ‘사상 첫 빅스텝’ “환율·물가 상승 우려”&amp;부동산 시장에 미치는 영향(최배근)[김어준의 뉴스공장]',
#     'description': '7월 14일(목) 김어준의 뉴스공장 ◎ 2부 [인터뷰 제1공장] 한은, 기준금리 2.25% 결정.. 사상 첫 빅스텝 물가·환율에 미칠 영향은?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g_eil4_O5TY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g_eil4_O5TY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g_eil4_O5TY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'TBS 시민의방송',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-13T23:09:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PR58NUqwwSowmcqqsheCyQ_ikug',
#    'id': {'kind': 'youtube#video', 'videoId': 'BseXl7U7ewU'},
#    'snippet': {'publishedAt': '2022-09-25T22:56:31Z',
#     'channelId': 'UCF4Wxdo3inmxP-Y59wXDsFw',
#     'title': '[재택플러스] &#39;또, 또‥&#39; 금리 인상에 증시도 출렁 (2022.09.26/뉴스투데이/MBC)',
#     'description': '미국의 계속된 긴축 정책에 세계 금융시장이 요동치고 있습니다. 원·달러 환율은 1400원을 돌파했고, 코스피는 연중 최저점을 뚫고 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BseXl7U7ewU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BseXl7U7ewU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BseXl7U7ewU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MBCNEWS',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-25T22:56:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LhfQUXVeSPECscUEX1yrtnEMKLk',
#    'id': {'kind': 'youtube#video', 'videoId': 'yK3vyZIsRyo'},
#    'snippet': {'publishedAt': '2022-05-13T07:12:57Z',
#     'channelId': 'UCF4Wxdo3inmxP-Y59wXDsFw',
#     'title': '[뉴스외전 경제 &#39;쏙&#39;] &quot;다다음 주 한국은행 금리인상 거의 확실&quot; (2022.05.13/뉴스외전/MBC)',
#     'description': '정철진 경제평론가 ----------- "최대 지급액 1천만원 여행, 항공, 공연 업종에 지급" "기재부, 작년에도 세수 61조 더 걷어..올해도 53조 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yK3vyZIsRyo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yK3vyZIsRyo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yK3vyZIsRyo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MBCNEWS',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-13T07:12:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7O9r89msDKFsojwJBetaIdqx5eA',
#    'id': {'kind': 'youtube#video', 'videoId': '7kbQ6hFE2zU'},
#    'snippet': {'publishedAt': '2020-04-21T12:35:18Z',
#     'channelId': 'UCy3ccMfJL911Wvk9x8XRVVg',
#     'title': '미국, 한국 은행에 대규모 벌금 부과, 그 파장은?',
#     'description': "'구독' 버튼을 눌러두시면 새로운 동영상을 실시간으로 받아보실 수 있습니다.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7kbQ6hFE2zU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7kbQ6hFE2zU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7kbQ6hFE2zU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '김영호교수의세상읽기',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-04-21T12:35:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CEWO6w1mcP5ClsbN0tZP8MahBrI',
#    'id': {'kind': 'youtube#video', 'videoId': 'cZKqLyoip6A'},
#    'snippet': {'publishedAt': '2019-04-04T03:44:59Z',
#     'channelId': 'UCc1C4tsjXcCpeyaS19_nGAA',
#     'title': '[114회] &#39;화폐개혁&#39; 꺼내든 한국은행 이주열의 속내는? ㅣ 최양오의 경제토크',
#     'description': "한국은행 이주열 총재가 지난달 25일 국회 업무보고에서 '리디노미네이션' 가능성을 언급했다. 단순히 화폐 숫자 단위만 바꾸는 효과 ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cZKqLyoip6A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cZKqLyoip6A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cZKqLyoip6A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '인포스탁데일리',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-04-04T03:44:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DtltMKcBXM91g6uGMZ62-Xl3Oew',
#    'id': {'kind': 'youtube#video', 'videoId': 'UPXiBLxCPa4'},
#    'snippet': {'publishedAt': '2021-02-25T09:55:39Z',
#     'channelId': 'UCcloDgiDqz8twby7zvG-USg',
#     'title': '한국은행 이주열 총재의 예상 못 한 폭탄 발언 나왔다!',
#     'description': '[쇼킹부동산] 한국은행 이주열 총재의 예상 못 한 폭탄 발언 나왔다! - 2월 금융통화위원회 결과 공유 - 이주열 한국은행 총재의 깜짝 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UPXiBLxCPa4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UPXiBLxCPa4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UPXiBLxCPa4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '쇼킹부동산',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-02-25T09:55:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'm8JFr1JKIVCVAyDIpS_WonbKEdk',
#    'id': {'kind': 'youtube#video', 'videoId': 'VWD4f2UIVEE'},
#    'snippet': {'publishedAt': '2020-05-17T03:32:13Z',
#     'channelId': 'UCaWi2foADm_lKAKnmeQwLSA',
#     'title': '한국은행 5월 기준금리 인하 초읽기 또 내려?',
#     'description': '재테크 부동산 투자자라면 알아야 할 내용 금리는 투자자라면 꼭 인지하고 친구처럼 지내야할 존재 과연 기준금리를 또 내릴것인가?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VWD4f2UIVEE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VWD4f2UIVEE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VWD4f2UIVEE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '재테크읽어주는 파일럿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-17T03:32:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'W0VksHhXs87x94VD_kybkX05x48',
#    'id': {'kind': 'youtube#video', 'videoId': 'LEmh_yMpFik'},
#    'snippet': {'publishedAt': '2021-07-11T03:00:09Z',
#     'channelId': 'UC1mySWSKdHfheY5rM9zu-Vg',
#     'title': '부동산 가계부채 폭탄, 모피아-금융위-한국은행의 작품',
#     'description': '채널에 가입하여 혜택을 누려보세요. https://www.youtube.com/channel/UC1mySWSKdHfheY5rM9zu-Vg/join 최배근TV 후원계좌: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LEmh_yMpFik/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LEmh_yMpFik/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LEmh_yMpFik/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '최배근TV',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-11T03:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6rhlveqM9uAY9BCQuteg4bJxXts',
#    'id': {'kind': 'youtube#video', 'videoId': 'QCYunyHdjGc'},
#    'snippet': {'publishedAt': '2022-01-15T05:00:10Z',
#     'channelId': 'UCsU-I-vHLiaMfV_ceaYz5rQ',
#     'title': '[자막뉴스] &quot;식단 이래도 나가서 먹으면 손해&quot;…한국은행 구내식당 들여다보니 / JTBC News',
#     'description': '작은 컵라면과 김밥 한 줄에 깍두기, 한국은행 지역본부 직원들이 구내식당 식단이 부실하다면서 올린 사진입니다. 안정적이고 처우도 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QCYunyHdjGc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QCYunyHdjGc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QCYunyHdjGc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JTBC News',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-15T05:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mwr3hKsiO-LLWvb1xrAizEJnb58',
#    'id': {'kind': 'youtube#video', 'videoId': 'Y2IWSxdPoAQ'},
#    'snippet': {'publishedAt': '2013-05-23T05:02:26Z',
#     'channelId': 'UCyK8niZNIfBTgRNkuURdoXA',
#     'title': '(한국은행) 화폐제조과정',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y2IWSxdPoAQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Y2IWSxdPoAQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Y2IWSxdPoAQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '한국은행',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-05-23T05:02:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZMb0yRBEVuYPuGKj1ZfinPC-yv8',
#    'id': {'kind': 'youtube#video', 'videoId': '4qsToFyTtfo'},
#    'snippet': {'publishedAt': '2022-09-22T22:25:45Z',
#     'channelId': 'UCF4Wxdo3inmxP-Y59wXDsFw',
#     'title': '[신선한 경제] 한국은행 &quot;빚내서 산 집값 하락 압력&quot; (2022.09.23/뉴스투데이/MBC)',
#     'description': '한국은행은 기준금리 인상이 주택가격에 하락 압력으로 작용할 가능성이 높다고 진단했습니다. 지난 5월 기준 우리나라 주택 가격은 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4qsToFyTtfo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4qsToFyTtfo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4qsToFyTtfo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MBCNEWS',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-22T22:25:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AIDuuNEYev9PAtz0OZd5L20F9kU',
#    'id': {'kind': 'youtube#video', 'videoId': 'OEfqbhGXP0E'},
#    'snippet': {'publishedAt': '2020-05-28T08:47:22Z',
#     'channelId': 'UCcloDgiDqz8twby7zvG-USg',
#     'title': '한국은행 금리 인하 결정! 0.5% 기준금리가 부를 재앙의 시작!',
#     'description': '[쇼킹경제] 0.5% 기준금리가 부를 재앙의 시작! - 기준금리 인하 배경은 무엇일까? - 초저금리가 부를 재앙의 시작은 무엇일까? 본 채널 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OEfqbhGXP0E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OEfqbhGXP0E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OEfqbhGXP0E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '쇼킹부동산',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-28T08:47:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'amtRofkSow4adTtYzkIwiqH4c7M',
#    'id': {'kind': 'youtube#video', 'videoId': 'fxBTSDbuLMg'},
#    'snippet': {'publishedAt': '2021-07-19T09:34:00Z',
#     'channelId': 'UCcloDgiDqz8twby7zvG-USg',
#     'title': '오늘 한국은행이 부동산에 폭탄을 던졌다!',
#     'description': '[쇼킹부동산] 오늘 한국은행이 부동산에 폭탄을 던졌다! - 한국은행 BOK 이슈노트가 화제된 이유 - 일본 부동산 버블 붕괴 과정과 한국 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fxBTSDbuLMg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fxBTSDbuLMg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fxBTSDbuLMg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '쇼킹부동산',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-19T09:34:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iZXhYZaFj8O8f473R9bEmzUnx68',
#    'id': {'kind': 'youtube#video', 'videoId': 'qFTK1NPuUUU'},
#    'snippet': {'publishedAt': '2019-05-27T13:00:26Z',
#     'channelId': 'UCPatzD-q7AYx-Zh1IBLPalQ',
#     'title': '공기업 No.1 한국은행은 SKY만 들어갈 수 있다??',
#     'description': '오랜만에 하는 이꾸!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qFTK1NPuUUU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qFTK1NPuUUU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qFTK1NPuUUU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '데드형',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-05-27T13:00:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'HLi7iZJNPF8eFebgak5--Zydoyw',
#    'id': {'kind': 'youtube#video', 'videoId': 'bO4IzBoimyQ'},
#    'snippet': {'publishedAt': '2022-05-29T06:33:16Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '연말 기준금리 2.5% 예상...물가 잡기 위한 한국은행 고심 깊어져 / YTN',
#     'description': '[앵커] 한국은행이 올해 물가 상승률 전망치를 3.1%에서 4.5%로 대폭 올리면서 물가 관리에 주력하겠다고 밝혔습니다. 이에 따라 기준 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bO4IzBoimyQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bO4IzBoimyQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bO4IzBoimyQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-29T06:33:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jI89Bmf3EyW60m5YwH7NlK6sr04',
#    'id': {'kind': 'youtube#video', 'videoId': 'FFvmQv9d68M'},
#    'snippet': {'publishedAt': '2011-10-07T07:21:33Z',
#     'channelId': 'UClAfLVQYZSLrMAQQ_SXPVZw',
#     'title': '[최진기의 뉴스위크 21강]한국은행, 이건 아니다',
#     'description': '더 많은 강의 영상은 www.ohmyschool.org 에서 볼 수 있습니다. 수능시장의 스타강사! 인문학 강의의 새장에 뛰어들다! 세상에서 가장 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FFvmQv9d68M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FFvmQv9d68M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FFvmQv9d68M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '오마이TV',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2011-10-07T07:21:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'K5nLGVksYQqLxfqavx0r_gKbQBw',
#    'id': {'kind': 'youtube#video', 'videoId': 'nKY7prCGYFM'},
#    'snippet': {'publishedAt': '2020-06-12T09:00:30Z',
#     'channelId': 'UCcloDgiDqz8twby7zvG-USg',
#     'title': '뒤늦게 발작한 주식시장, 한국은행의 폭탄 선언!',
#     'description': '[쇼킹경제] 뒤늦게 발작한 증시, 한국은행의 폭탄 선언! - 미국 증시 하락에 대한 원인은? - 한국은행에 언급한 충격적인 발언은?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nKY7prCGYFM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nKY7prCGYFM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nKY7prCGYFM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '쇼킹부동산',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-06-12T09:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Aa-UQMPN61_jTPp1_BRitbo2Fdk',
#    'id': {'kind': 'youtube#video', 'videoId': 'GPa1Cs4XVDA'},
#    'snippet': {'publishedAt': '2020-10-21T12:48:38Z',
#     'channelId': 'UCsU-I-vHLiaMfV_ceaYz5rQ',
#     'title': '이토 히로부미 &#39;친필&#39; 확인…한국은행 머릿돌 어쩌나 / JTBC 뉴스룸',
#     'description': '서울 명동에 가면 자주 보는 건물일 겁니다. 지금은 화폐박물관으로 쓰이는 한국은행 본관이죠. 이 건물 모퉁이에 을사조약을 체결한 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GPa1Cs4XVDA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GPa1Cs4XVDA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GPa1Cs4XVDA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JTBC News',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-10-21T12:48:38Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P82rZV0j7jXBdf9myUY7Tyq6H5w',
#    'id': {'kind': 'youtube#video', 'videoId': 'eurNlMJ-h00'},
#    'snippet': {'publishedAt': '2022-05-05T11:37:20Z',
#     'channelId': 'UCkinYTS9IHqOEwR1Sze2JTw',
#     'title': '미국 &#39;빅 스텝&#39;, 한국은행도 따라가나? &quot;대출 대비 필요&quot; / SBS',
#     'description': '미국이 이렇게 나오면 우리나라도 영향을 받을 수밖에 없습니다. 당장 한국은행이 지난달에 이어서 두 달 연속 금리를 올릴 가능성이 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eurNlMJ-h00/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eurNlMJ-h00/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eurNlMJ-h00/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SBS 뉴스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-05T11:37:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2TwDvrCSHo8yBtdgJmMj4eRrFCg',
#    'id': {'kind': 'youtube#video', 'videoId': 'm0eYZNofMuY'},
#    'snippet': {'publishedAt': '2022-04-14T01:31:55Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '한국은행, 고물가 비상에 기준금리 인상...연 1.5% / YTN',
#     'description': '[앵커] 한국은행 금융통화위원회가 기준금리를 또 한 번 높였습니다. 최근 물가 상황이 심상치 않다는 판단에 따른 것으로 풀이됩니다.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/m0eYZNofMuY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/m0eYZNofMuY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/m0eYZNofMuY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-14T01:31:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sR1MHQ0ao3JG-wJkFARqVpDxmBw',
#    'id': {'kind': 'youtube#video', 'videoId': 'QDDOj-XjOhM'},
#    'snippet': {'publishedAt': '2021-01-01T16:35:42Z',
#     'channelId': 'UCpawkohlbS490M0B-KfjIBA',
#     'title': '2021년 한국은행 경제전망 어떤산업 어떤종목에 투자할까?',
#     'description': '피셔인베스트 후원하기 투네이션 https://toon.at/donate/636955907770392295 우리은행 1002-942-546994 박*협 상담 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QDDOj-XjOhM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QDDOj-XjOhM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QDDOj-XjOhM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '피셔인베스트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-01-01T16:35:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'm3wI1WlTmcBxwtTDFoa62IvSxIA',
#    'id': {'kind': 'youtube#video', 'videoId': 'OXFnA3aombw'},
#    'snippet': {'publishedAt': '2022-06-27T05:40:58Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '[더뉴스] 6%대로 치솟는 소비자 물가... &#39;빅스텝&#39; 앞에 선 한국은행 / YTN',
#     'description': '진행 : 김영수 앵커, 엄지민 앵커 □ 출연 : 정철진 / 경제평론가 * 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으니 보다 정확한 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OXFnA3aombw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OXFnA3aombw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OXFnA3aombw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-27T05:40:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2xzBuES3sQCaFhoYCD-pCCQhzsg',
#    'id': {'kind': 'youtube#video', 'videoId': 'zBtg_pOeOTs'},
#    'snippet': {'publishedAt': '2022-07-10T07:46:44Z',
#     'channelId': 'UChlgI3UHCOnwUGzWzbJ3H5w',
#     'title': '한국은행, 사상 첫 &#39;빅스텝·3연속 금리 인상&#39; 하나? / YTN',
#     'description': '진행 : 김영수 앵커 □ 출연 : 주 원 / 현대경제연구원 경제연구실장 * 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으니 보다 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zBtg_pOeOTs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zBtg_pOeOTs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zBtg_pOeOTs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': ' YTN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-10T07:46:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '20nhF9EMwtYjhnWrxFEO2es-25M',
#    'id': {'kind': 'youtube#video', 'videoId': '6vM6Y8eqLqI'},
#    'snippet': {'publishedAt': '2021-06-10T09:13:11Z',
#     'channelId': 'UCcloDgiDqz8twby7zvG-USg',
#     'title': '한국은행 폭탄 발언에 난리 난 이유!',
#     'description': '[쇼킹부동산] 한국은행 폭탄 발언에 난리 난 이유! - 통화신용정책 보고서 기자설명회 발언 정리 - 왜 긴축이 아니라는 한국은행 답변이 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6vM6Y8eqLqI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6vM6Y8eqLqI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6vM6Y8eqLqI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '쇼킹부동산',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-10T09:13:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mM7xm-j2OzqPZzI2vCWneSU0tVM',
#    'id': {'kind': 'youtube#video', 'videoId': 'IdjE_k25Yb8'},
#    'snippet': {'publishedAt': '2022-07-10T15:35:00Z',
#     'channelId': 'UCj2gpUrZ7LMp4Mp1pVMKz0g',
#     'title': '한국은행  빅스탭 3회 예정 자산시장 충격과 공포 진행... 다음주 월요일 부터는   자산시장은 본격적인 하락장',
#     'description': '우리 은행 (대동포럼) 박 홍기 후원계좌 1005 - 203 - 205878 대동포럼 소액 후원을 환영하며 10만원 이상은 정중하게 사절 합니다.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IdjE_k25Yb8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IdjE_k25Yb8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IdjE_k25Yb8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '박 홍기  작가  TV     삶 테크 ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-10T15:35:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'U8cgodaEyOWWgKh1uYLvtIDu3FM',
#    'id': {'kind': 'youtube#video', 'videoId': 'mhjrv20kHhI'},
#    'snippet': {'publishedAt': '2021-12-10T06:30:12Z',
#     'channelId': 'UCGF6SQDqskBZXubOiHiuq8Q',
#     'title': '[정완진TV] 한국은행 &#39;섬뜩한 경고&#39;...&quot;금융위기 터진다?&quot; [멋진아재TV]',
#     'description': '[정완진TV] 한국은행 \'섬뜩한 경고\'..."금융위기 터진다?" [멋진아재TV] 한국은행 \'섬뜩한 경고\'..."금융위기 터진다?" 영상을 봐주세요~ ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mhjrv20kHhI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mhjrv20kHhI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mhjrv20kHhI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '정완진TV',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-10T06:30:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_v6XhmtZoo5K9zME9j4VonsJyPU',
#    'id': {'kind': 'youtube#video', 'videoId': '2lBo6V3d_gE'},
#    'snippet': {'publishedAt': '2022-08-16T09:04:33Z',
#     'channelId': 'UC4E394G9WuS9y6SlBZslMsQ',
#     'title': '쩐썰의 오건영 ㅣ한국은행 사상 첫 &#39;빅스텝&#39; 금리인상이 가져올 득실은 (Ep.23)',
#     'description': "세상 모든 '쩐  '에 관한 '썰    \u200d  ' '쩐썰의 오건영'의 쩐썰 클래스 시간이 돌아왔습니다! 오늘의 주제는? '한국은행 기준금리 인상'에 ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2lBo6V3d_gE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2lBo6V3d_gE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2lBo6V3d_gE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '신한은행',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-16T09:04:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lhqWELE42Y4eqLd0H_gcO_24RsY',
#    'id': {'kind': 'youtube#video', 'videoId': 'cM3WHFXYBt4'},
#    'snippet': {'publishedAt': '2022-09-29T01:43:17Z',
#     'channelId': 'UC3dYEYtdihZpsexdC9-qKDA',
#     'title': '달러 1500원 시대? 환율 대란과 어두운 경제',
#     'description': '9/26일 월요일에 촬영한 영상입니다. 업로드 시점에서 outdated된 정보가 있을 수 있습니다. #환율 #달러 #킹달러 #엔화 #정부개입 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cM3WHFXYBt4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cM3WHFXYBt4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cM3WHFXYBt4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '뉴욕주민',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-29T01:43:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dbjkL8xV0z-dd1GwgtFh-JJBHq0',
#    'id': {'kind': 'youtube#video', 'videoId': 'cz_lYPsihFg'},
#    'snippet': {'publishedAt': '2020-08-06T01:41:21Z',
#     'channelId': 'UCyK8niZNIfBTgRNkuURdoXA',
#     'title': '[한국은행] 입행이 궁금해? 1편!',
#     'description': '2021년 한국은행 입행을 준비하시는 취준생 여러분! 댓글로 달아주신 궁금했던 점들을 한국은행의 상큼발랄한 신입직원들이 답변 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cz_lYPsihFg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cz_lYPsihFg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cz_lYPsihFg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '한국은행',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-08-06T01:41:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ON6wIA1ruq_4nQQebUDpjthIFkI',
#    'id': {'kind': 'youtube#video', 'videoId': 'NN-cyIeqOHE'},
#    'snippet': {'publishedAt': '2018-10-14T00:00:01Z',
#     'channelId': 'UCy3ccMfJL911Wvk9x8XRVVg',
#     'title': '미국 재무성, 한국 은행과 기업에게 &#39;세컨더리 보이콧&#39; 위험성 경고하다',
#     'description': "'구독' 버튼을 눌러두시면 새로운 동영상을 실시간으로 받아보실 수 있습니다. **이 동영상 관련 자료: 1. 미국 재무성 북한 제재 관련 ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NN-cyIeqOHE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NN-cyIeqOHE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NN-cyIeqOHE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '김영호교수의세상읽기',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-10-14T00:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ro4eLQTYctM4y8uLaVFO_JlPix8',
#    'id': {'kind': 'youtube#video', 'videoId': 'vUsmmorkfoU'},
#    'snippet': {'publishedAt': '2021-06-15T00:11:17Z',
#     'channelId': 'UC98Cn9p3DCEffXA6aZ1M0Hw',
#     'title': '한국은행 기준금리 인상과 부동산 투자의 기준 - 금리인상 발언과 지급준비율, IOER로 본 보충적 통화정책',
#     'description': '부동산전망 #IOER #지급준비율 2021년 부동산 전망에 있어, 미국 재무장관 재닛 옐런의 거듭된 금리인상 발언에 이어, 한국은행 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vUsmmorkfoU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vUsmmorkfoU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vUsmmorkfoU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '자유지성 - Liberal Reason',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-15T00:11:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'HIJfrnRRFNUgAMY4n-TEB4ugATM',
#    'id': {'kind': 'youtube#video', 'videoId': '8TVoNWMe5zg'},
#    'snippet': {'publishedAt': '2022-02-14T09:06:05Z',
#     'channelId': 'UCcloDgiDqz8twby7zvG-USg',
#     'title': '주말에 한국은행이 부동산에 폭탄을 던졌다!',
#     'description': '아파트 교과서 책 : https://blog.naver.com/jdliksa12/222482668108 [쇼킹부동산] 주말에 한국은행이 부동산에 폭탄을 던졌다!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8TVoNWMe5zg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8TVoNWMe5zg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8TVoNWMe5zg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '쇼킹부동산',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-14T09:06:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AJ9PeBjhxj3AioKm8X7viWpevoI',
#    'id': {'kind': 'youtube#video', 'videoId': 'S_zqoReKPe0'},
#    'snippet': {'publishedAt': '2022-06-22T14:21:57Z',
#     'channelId': 'UCj2gpUrZ7LMp4Mp1pVMKz0g',
#     'title': '한국은행 금융안정 보고서 2022.06 공개..충격.. 아시아 외환위기급 사태.. 터질 가능성 높다.',
#     'description': '우리 은행 (대동포럼) 박 홍기 후원계좌 1005 - 203 - 205878 대동포럼 소액 후원을 환영하며 10만원 이상은 정중하게 사절 합니다.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/S_zqoReKPe0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/S_zqoReKPe0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/S_zqoReKPe0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '박 홍기  작가  TV     삶 테크 ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-22T14:21:57Z'}}]}

# %%
import pandas as pd

# %%
# 데이터프레임을 만들기 위해 임시로 사용할 dictionary
dict_video_list = { "영상ID":[], "영상제목":[], "영상설명":[], "영상게시일시":[], "채널명":[], "영상조회":[], "영상좋아요":[], "댓글수":[] }

# 검색결과로 나온 영상 정보를 dictionary에 저징
for video in video_list["items"]:
    dict_video_list["영상ID"].append(video['id']['videoId'].strip())
    dict_video_list["영상제목"].append(video["snippet"]['title'].strip())
    dict_video_list["영상설명"].append(video["snippet"]['description'].strip())
    dict_video_list["영상게시일시"].append(video["snippet"]['publishTime'].strip())
    dict_video_list["채널명"].append(video["snippet"]['channelTitle'].strip())
        
    # 조회수, 좋아요, 댓글 수와 같은 통계정보 얻기
    videoId = video['id']['videoId'].strip()
    video_stat = youtube.videos().list(
        part='statistics',
        id = videoId
    ).execute()   
    
    dict_video_list["영상조회"].append(video_stat['items'][0]['statistics']["viewCount"])
    if "likeCount" in video_stat['items'][0]['statistics'].keys():
        dict_video_list["영상좋아요"].append(video_stat['items'][0]['statistics']["likeCount"])
    else:
        dict_video_list["영상좋아요"].append(0)
            
    if "commentCount" in video_stat['items'][0]['statistics'].keys():
        dict_video_list["댓글수"].append(video_stat['items'][0]['statistics']["commentCount"])
    else:
        dict_video_list["댓글수"].append(0)

# dictionary를 데이터 프레임으로 변환
df_video_list = pd.DataFrame(dict_video_list)

# %%
df_video_list.head()
# Out:
#           영상ID                                               영상제목  \
# 0  V5xVcFhIX2s            [자막뉴스] 덜컥 다가온 외환위기 악몽...다급해진 한국은행 / YTN
# 1  Jdq7Ztc9XLE         독일 은행원 언니, 여동생 따라 간 은행에 충격! (한국은행 실제반응 ㅋㅋ)
# 2  k-EQ7ofeTYw  [에디터픽] &quot;韓, 아시아서 가장 위험&quot;..&#39;제2 IMF&...
# 3  vfGY0qycl1g  [자막뉴스] 영끌족 &#39;발등에 불&#39;...한은 총재까지 &#39;섬뜩한 ...
# 4  6WaB2fGpNN4              [자막뉴스] 美가 쏘아올린 시한폭탄...벼랑 끝 한국은행 / YTN
#
#                                                 영상설명                영상게시일시  \
# 0  7월 소비자물가가 1년 전보다 6.3% 올랐습니다. 외환위기 때인 1998년 11월...  2022-08-03T02:07:28Z
# 1  독일 은행에서 일하는 에밀리의 친언니, 아나! 아나가 한국은행에서 보고 놀란 장면들...  2022-01-25T09:15:00Z
# 2  1.'킹달러' 세계 금융시장 강타...총성 없는 '환율 전쟁'(김상우 기자) 2.O...  2022-09-27T08:12:02Z
# 3  은행권 주택담보대출 변동금리의 기준인 코픽스가 7월에 0.52%포인트 상승해 2.9...  2022-08-17T10:44:16Z
# 4  미국의 문제도 역시 인플레이션입니다. 지난달 소비자물가는 1년 전보다 8.3% 올라...  2022-09-19T08:32:21Z
#
#                     채널명     영상조회  영상좋아요   댓글수
# 0                   YTN  1912395  11478  4742
# 1  어썸 코리아 Awesome KOREA  1807815  35608  1291
# 2                   YTN  1165971   8958  2162
# 3                   YTN   837135   5353  2007
# 4                   YTN   643041   4309  2151

# %%
# 앞서 수집한 각 영상에 입력된 댓글을 수집
dict_comments = { "영상ID":[], "댓글":[], "댓글작성자":[], "댓글작성일시":[], "댓글좋아요":[], "대댓글":[] }

for i in notebook.tqdm(range(len(df_video_list.iloc[0:3])), desc="유튜브 영상 댓글 수집"):
  video = df_video_list.iloc[i]  # 영상정보 얻기    
  nextPageToken = ""  # 다음페이지 조회를 위한 토큰값
  numPages = 1  # 페이지 수
  
  try:
    while nextPageToken != None:
      # NextPage Token이 결과에 나오면 다음 페이지가 있다는 의미
      comment_list = youtube.commentThreads().list(
        part='snippet,replies',
        videoId=video["영상ID"],     # 댓글을 수집할 영상 ID
        maxResults=100,          # 영상별 100개의 댓글 수집 (대댓글은 포함하지 않음)
        order='relevance',       # 연관성 기준으로 정렬
        textFormat='plainText',  # 텍스트 포맷
        pageToken=nextPageToken      # 앞 페이지 조회시 얻은 nextPageToken 값
      ).execute()

      for comment in comment_list["items"]:
        dict_comments["영상ID"].append(comment['snippet']['videoId'].strip())
        dict_comments["댓글"].append(comment['snippet']['topLevelComment']['snippet']['textDisplay'].strip())
        dict_comments["댓글작성자"].append(comment['snippet']['topLevelComment']['snippet']['authorDisplayName'].strip())
        dict_comments["댓글작성일시"].append(comment['snippet']['topLevelComment']['snippet']['publishedAt'].strip())
        dict_comments["댓글좋아요"].append(comment['snippet']['topLevelComment']['snippet']['likeCount'])
        dict_comments["대댓글"].append(comment['snippet']['totalReplyCount'])

      # 다음 페이지가 있는 경우
      if "nextPageToken" in comment_list.keys():
        #nextPageToken = comment_list["nextPageToken"]
        # 실습을 위해서 일단 영상별로 100개의 댓글만 수집합니다. 
        # 100개 이상을 수집하기 위해서는 위의 코드를 사용하세요.
        nextPageToken = None 
      else:
        nextPageToken = None
      numPages += 1  # 페이지 수 증가

  except:
    # 댓글을 차단하는 경우 오류가 발생할 수 있는데 이때 그냥 넘겨버림    
    continue
# Out:
# 유튜브 영상 댓글 수집:   0%|          | 0/50 [00:00<?, ?it/s]
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"

# %%
# dictionary를 데이터 프레임으로 변환
df_comments = pd.DataFrame.from_dict(dict_comments)

# %%
df_comments.head()
# Out:
#           영상ID                                                 댓글     댓글작성자  \
# 0  V5xVcFhIX2s  1998년도 외환 위기는 한국을 포함한 몇몇나라에서만 문제였고 세계경제는 특별한 문...   메존일각고다이
# 1  V5xVcFhIX2s  한국의 가계부채 비중과 그 용도를 생각했을 때 단순히 금리를 인상해서 소비자 물가가...      라지피자
# 2  V5xVcFhIX2s  소잃고 외양간 고치지말고 우리나라도 0.5,  0.75, 과감하게 단기간에 올려 물...      제이제이
# 3  V5xVcFhIX2s  이 보도 본 뒤 국가부도의 날 또 보고 왔습니다\n위기는 정말 주기적으로 돌아오네요...  튀밥먹는튀밥냥이
# 4  V5xVcFhIX2s             최대 외환보유의 시대에서 곧바로 이런 지경까지 이르게 되다니...ㅠㅠ       유준치
#
#                  댓글작성일시  댓글좋아요  대댓글
# 0  2022-08-09T03:21:26Z    675  157
# 1  2022-08-03T22:35:50Z    408   36
# 2  2022-08-04T04:56:22Z    566    3
# 3  2022-08-07T12:07:07Z    269   10
# 4  2022-08-08T19:50:03Z    447   11

# %%
df_comments.tail()
# Out:
#               영상ID                                                댓글   댓글작성자  \
# 16886  S_zqoReKPe0                                cbdc진짜..현생인류 멸종각..  kj kim
# 16887  S_zqoReKPe0                                             안녕하세요     강일수
# 16888  S_zqoReKPe0  이미 끝난 정권이다\n각자도생 합시다\n검소한 생활이 자기를 살린다 굥 믿지말고 삽시다    利在田田
# 16889  S_zqoReKPe0                                                 1     전현일
# 16890  S_zqoReKPe0                                굥짬뽕에 여러사람 골로가네 ㅋㅋㅋ     안정적
#
#                      댓글작성일시  댓글좋아요  대댓글
# 16886  2022-06-22T14:31:03Z     17    0
# 16887  2022-06-22T15:54:25Z     14    0
# 16888  2022-06-23T00:25:48Z     13    0
# 16889  2022-06-22T21:11:57Z      7    0
# 16890  2022-06-22T23:38:27Z      7    0

# %%
# 영상ID를 사용해서 각 댓글이 작성된 영상의 제목과 설명을 추가
df_new_comments = df_comments.join(df_video_list[["영상ID", "영상제목", "영상설명"]].set_index("ID"), on="영상ID", how="left")

# %%
df_new_comments.head()
# Out:
#           영상ID                                                 댓글        작성자  \
# 0  V5xVcFhIX2s  1998년도 외환 위기는 한국을 포함한 몇몇나라에서만 문제였고 세계경제는 특별한 문...    메존일각고다이
# 1  V5xVcFhIX2s  이 보도 본 뒤 국가부도의 날 또 보고 왔습니다\n위기는 정말 주기적으로 돌아오네요...   튀밥먹는튀밥냥이
# 2  V5xVcFhIX2s             최대 외환보유의 시대에서 곧바로 이런 지경까지 이르게 되다니...ㅠㅠ        유준치
# 3  V5xVcFhIX2s  솔직히 서브프라임에서 시작된 저금리 기조를 전세계가 그만둘 타이밍을 놓쳐버린게 크다...        용가리
# 4  V5xVcFhIX2s  대한민국은 처음부터 금리를 좀 높게 잡고있어야 했다 그래서 레버리지를 못쓰게 만들었...  Json Choi
#
#                    작성일시   좋아요  대댓글                                       제목  \
# 0  2022-08-09T03:21:26Z   674  157  [자막뉴스] 덜컥 다가온 외환위기 악몽...다급해진 한국은행 / YTN
# 1  2022-08-07T12:07:07Z   269   10  [자막뉴스] 덜컥 다가온 외환위기 악몽...다급해진 한국은행 / YTN
# 2  2022-08-08T19:50:03Z   446   11  [자막뉴스] 덜컥 다가온 외환위기 악몽...다급해진 한국은행 / YTN
# 3  2022-08-06T06:13:55Z   197   32  [자막뉴스] 덜컥 다가온 외환위기 악몽...다급해진 한국은행 / YTN
# 4  2022-08-03T02:22:21Z  1692  162  [자막뉴스] 덜컥 다가온 외환위기 악몽...다급해진 한국은행 / YTN
#
#                                                   설명
# 0  7월 소비자물가가 1년 전보다 6.3% 올랐습니다. 외환위기 때인 1998년 11월...
# 1  7월 소비자물가가 1년 전보다 6.3% 올랐습니다. 외환위기 때인 1998년 11월...
# 2  7월 소비자물가가 1년 전보다 6.3% 올랐습니다. 외환위기 때인 1998년 11월...
# 3  7월 소비자물가가 1년 전보다 6.3% 올랐습니다. 외환위기 때인 1998년 11월...
# 4  7월 소비자물가가 1년 전보다 6.3% 올랐습니다. 외환위기 때인 1998년 11월...
